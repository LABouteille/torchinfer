# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchinfo
import onnx
import torch.onnx

# %%
class SimpleNet(nn.Module):
    def __init__(self, num_classes=10, init_weights=True):
        super(SimpleNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=3, kernel_size=4, stride=2)
        self.conv2 = nn.Conv2d(in_channels=3, out_channels=5, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(in_channels=5, out_channels=5, kernel_size=4, stride=2)

        self.linear1 = nn.Linear(in_features=5 * 2 * 2, out_features=10)
        self.linear2 = nn.Linear(in_features=10, out_features=num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = torch.flatten(x, start_dim=1)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        return x

# %%
model = SimpleNet()
    
torchinfo.summary(model, input_size=(16, 1, 32, 32))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SimpleNet                                [16, 10]                  --
# ├─Conv2d: 1-1                            [16, 3, 15, 15]           51
# ├─Conv2d: 1-2                            [16, 5, 6, 6]             245
# ├─Conv2d: 1-3                            [16, 5, 2, 2]             405
# ├─Linear: 1-4                            [16, 10]                  210
# ├─Linear: 1-5                            [16, 10]                  110
# ==========================================================================================
# Total params: 1,021
# Trainable params: 1,021
# Non-trainable params: 0
# Total mult-adds (M): 0.36
# ==========================================================================================
# Input size (MB): 0.07
# Forward/backward pass size (MB): 0.11
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.18
# ==========================================================================================

# %%
x = torch.randn(16, 1, 32, 32, requires_grad=True)
model = model.cpu()
x = x.cpu()

# Export the model
torch.onnx.export(model,                     # model being run
                  x,                         # model input (or a tuple for multiple inputs)
                  "model.onnx",              # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=13,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['input'],   # the model's input names
                  output_names = ['output'], # the model's output names
                  dynamic_axes={'input' : {0 : 'batch_size'},    # variable length axes
                                'output' : {0 : 'batch_size'}})

# %%
def onnx_check_model(onnx_model):
    try:
        onnx.checker.check_model(onnx_model)
    except onnx.checker.ValidationError as e:
        print('The model is invalid: %s' % e)
    else:
        print('The model is valid!')

model_onnx = onnx.load("model.onnx")
onnx_check_model(model_onnx)
# Out:
# The model is valid!

# %%
print(model_onnx.graph.initializer[0].dims)
print(model_onnx.graph.initializer[1].dims)
print(model_onnx.graph.initializer[2].dims)
print(model_onnx.graph.initializer[3].dims)
# Out:
# [3, 1, 4, 4]
# [3]
# [5, 3, 4, 4]
# [5]

# %%
model_onnx.graph.node[0]
# Out:
# input: "input"
# input: "conv1.weight"
# input: "conv1.bias"
# output: "x"
# name: "Conv_0"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 4
#   ints: 4
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }

# %%
from collections import OrderedDict
from enum import IntEnum
from typing import Dict, Optional, List

class TYPEDEF:
    ONNX_MODEL = onnx.onnx_ml_pb2.ModelProto
    ONNX_NODE = onnx.onnx_ml_pb2.NodeProto
    ONNX_IR = OrderedDict

class OPTYPE(IntEnum):
    CONV2D = 0
    RELU = 1
    FLATTEN = 2
    LINEAR = 3

    def __repr__(self):
        return self.name
    
    def __str__(self):
        return self.name

class DTYPE(IntEnum):
    # https://github.com/onnx/onnx/blob/master/onnx/onnx.in.proto#L483-L485
    FLOAT = 1,   # float
    INT8 =  3,   # int8_t
    INT16 = 4,   # int16_t
    INT32 = 6,   # int32_t
    INT64 = 7    # int64_t

    def __repr__(self):
        return self.name
    
    def __str__(self):
        return self.name

def dump_onnx_model(ir: TYPEDEF.ONNX_IR) -> None:
    pass

def get_attributes(node: TYPEDEF.ONNX_NODE) -> OrderedDict:
    return OrderedDict()

def get_dtype(data_type: int) -> DTYPE:
    if data_type == DTYPE.FLOAT:
        return DTYPE.FLOAT
    elif data_type == DTYPE.INT8:
        return DTYPE.INT8
    elif data_type == DTYPE.INT16:
        return DTYPE.INT16
    elif data_type == DTYPE.INT32:
        return DTYPE.INT32
    else:
        return DTYPE.INT64

def get_optype(node: TYPEDEF.ONNX_NODE) -> OPTYPE:
    optype = node.op_type.lower()

    if optype == "conv":
        return OPTYPE.CONV2D
    elif optype == "relu":
        return OPTYPE.RELU
    elif optype == "gemm":
        return OPTYPE.LINEAR
    elif optype == "flatten":
        return OPTYPE.FLATTEN
    else:
        raise NotImplementedError("get_optype: Operator type not implemented yet.")    

def get_initializer(node: TYPEDEF.ONNX_NODE) -> Dict[Dict, Optional[Dict]]:
    """
    {
       weight: {
            name:
            raw_data:
            dims:
            data_type:
       },
       bias: {
            name:
            raw_data:
            dims:
            data_type:
       }   
    }
    """
    initializer = dict()
    initializer["weight"], initializer["bias"] = {}, {}
    
    for inp in node.input:
        for init in model_onnx.graph.initializer:
            if inp == init.name:
                if len(init.dims) > 1:
                    initializer["weight"]["name"] = init.name
                    initializer["weight"]["raw_data"] = init.raw_data
                    initializer["weight"]["dims"] = list(init.dims)
                    initializer["weight"]["data_type"] = get_dtype(init.data_type)
                else:
                    initializer["bias"]["name"] = init.name
                    initializer["bias"]["raw_data"] = init.raw_data
                    initializer["bias"]["dims"] = list(init.dims)
                    initializer["bias"]["data_type"] = get_dtype(init.data_type)

    return initializer

def get_inputs(node: TYPEDEF.ONNX_NODE) -> List[int]:
    pass

def get_outputs(node: TYPEDEF.ONNX_NODE) -> List[int]:
    pass

def parse_onnx_model(model: TYPEDEF.ONNX_MODEL) -> OrderedDict:
    """
    OrderedDict
    {
        inputs: []

        node_ith: {
            op_type: OPTYPE
            name: str 
            inputs: List
            outputs: List
            initializer: Dict
            attributes: {}
            data_layout: [NCHW, NHWC]
        }

        outputs: []
    }

    Returns an intermediate representation of ONNX model
    """
    ir = OrderedDict()

    # ir["inputs"] = [inp.name for inp in model.graph.input]
    
    for i, node in enumerate(model.graph.node):
        ir[i] = {}
        ir[i]["name"] = node.name
        ir[i]["op_type"] = get_optype(node)
        ir[i]["inputs"] = get_inputs(node)
        ir[i]["outputs"] = get_outputs(node)
        ir[i]["initializer"] = get_initializer(node)
        ir[i]["attributes"] = get_attributes(node)
        ir[i]["data_layout"] = None
        

    # ir["outputs"] = [out.name for out in model.graph.output]

    return ir

ir = parse_onnx_model(model_onnx)

# %%
ir
# Out:
# OrderedDict([(0,
#               {'name': 'Conv_0',
#                'op_type': CONV2D,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {'name': 'conv1.weight',
#                  'data_type': FLOAT},
#                 'bias': {'name': 'conv3.bias',
#                  'raw_data': b'\xfd\x0fu=\x06\x111\xbd\x8e\xd7\xae\xbdU\x9e\x84\xbc\x8b\xd4P\xbd',
#                  'dims': [5],
#                  'data_type': FLOAT}},
#                'attributes': OrderedDict(),
#                'data_layout': None}),
#              (5,
#               {'name': 'Relu_5',
#                'op_type': RELU,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {}, 'bias': {}},
#                'attributes': OrderedDict(),
#                'data_layout': None}),
#              (6,
#               {'name': 'Flatten_6',
#                'op_type': FLATTEN,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {}, 'bias': {}},
#                'attributes': OrderedDict(),
#                'data_layout': None}),
#              (7,
#               {'name': 'Gemm_7',
#                'op_type': LINEAR,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {'name': 'linear1.weight',
#                  'raw_data': b'\xf3\x8fW\xbe\xcb\xb4<\xbd\x18\x05K>\x19\x92\x01>S9\xa7\xbdKYX\xbe\x7fJ\xa5=\x16=\x82\xbd3\xa9\x90\xbc\x85\x83\x18\xbe\xfb\t=>\x11L`\xbe\xa1\x98W>\xc0\xa0\\\xbe8\xf4\xbf\xbcQ\x04\xfc\xbc\x0ff\xc4\xbd\xbdl9\xbeC\xa86\xbd\x9eM >\xee\xf7\xd1\xbd\x87\xfd\xed\xbc\xa7[!>\xef]\xb2\xbd+3\x1a>\xf4\x02">\xc7\xe9\xdc\xbd\x91\xaf4\xbe\xbe\x9fH\xbd\x8e\xf8\xed\xbb\x01J\xe0\xbdq\x03\xfd=\x0f\xd4E\xbe\x9c^&\xbc\xbf\x9a\xcd<\x87\xaf\xea=1\x18\x8a\xbd\x11]p=DLZ>$\x97P\xber\x8d;>\xf7GQ="#\x08\xbe\x0b\\\xde=\xc7;\x1c>Z\xe3G\xbd\x8b\x0eD\xbe\xe3wR>\x81-\xc7\xbdw\xe6:>\xcd{\xff\xbd\x9f]\xa8\xbd\xb8\x19\xd0\xbd\xe6\x92\xee<<~\x12\xbe\x1b\x7f\x1c>\x89:\x1d\xbe\xa2\xec\xe5=-i\x88\xbc!=\xcf=\x7f\x8c\xde\xbdqu\x94=\xf8ec\xbe\r\xbdR\xbd3A.\xbe3W\x18\xbeR\xc6\xb5=i\x15\x1c>\x18\rE\xbe\xea&:\xbe\xa9\xdb->\xb5j\xba=)?\x13=\xa4\x84}=\x82t\xe2\xbdA\x11H\xbe\xb8\xc7K=$(\xa2\xbdRW\x9a\xbd<E%>\xdd\xdf\xaa=\xf1\xbc\x05\xbd\x85Q\x99=L\xb6\x1d\xbeb\xbe\x1d>\xf4\xf4\x7f<\xfb\xf6x\xbd\xde:g\xbd\xc7W\x9f\xbdZ\xf25\xbe\xe6\x82\xd1=\x15&|\xbd\x81-3>\x86\x1eV\xbe6\xdf\xbd\xbd%\x1b\xab=\\\x0cX\xbdh\xedR\xbeUa\xe9<\x06\x94&>B\xe8\xf5\xbd$\xcf\xcc=\xd7\xb7\x9d\xbd\xc8\xbc9\xbdP\x8c\xd6;N\xf74\xbdL\xed5\xbe\x87pE=\xee\x9b\t\xbe}>\xb9=\x9b.Y\xbe\xa9\xc8S>\xa2\xc9H>($\x19>\x14\xb0H>A\xeaA\xbe\xb8\x15H\xbe\xf5+B=\xae\xbc\xfb=#\x95\xf7\xbd{\x9a#>\x8a\x84M\xbe\x94vz<\xfc\xed\x1e=\t\xa6Z\xbe?R\xc0=\x90\xdeY>B0\x02\xbe\x85 M>o_\x0e\xbe\x14\x9c\t\xbe\xcf\xdd/\xbe\x05\xc2\xd5\xbd\x1d\xf4"\xbd\xdc\xa5\x99=\xa1\xdf\xf1=\x9e\xdc\xf5\xbb\x06gS=\x1e\x0f`\xbe\xbdY\xc8=\xb8\xf65\xbe_\xc07\xbe4\r\x0b\xbe\t\x83"\xbe\x02\xa0\x84<\xb5G\x10\xbdt\xcdl\xbdZ\xee\xc6=\xb9\xb4`>\x15\xc5e\xbd\xfc\x11\x0f\xbdW\xc0\x17\xbe\xbb\xda0>\x19\xfd\x8b=A\x86:>\x93;\x0f=\xe7a\xca\xbd\xe8\xb0\x1b<>_0\xbc7gq=\xbd1\xc6\xbd\xbc\xe3\x0f>\x87i\xbf\xbd\xe1|H\xbe\xc8\xf9;>\xb6"I\xbe\x1cl\n\xbe\xf7\xea\xfa<\xc3B\x0b\xbe{\xf5\xed=c\xf0Z\xb9\x12t\xca=z\xe8\x07>\x15k\xa1\xbdZx\x17=5\xec\xf9=<\x16\xcf=\xb2\xe3\x12>s3J>@X\xcc\xbd\x0b\xe3\xfc=\xbf\xbc\x06=M2\xef\xbd\xdb\xabY\xbe\x17\xd6Z\xbe\xee\xa9\xc1=H^1>\x14`\x90\xbc\xf0\x9f1\xbezF\xae<\x9b_\x11=jr\x14>\xeev\x88<B\x7fP\xbel\xb8H=\xaf\xc0_\xbcb\x98D\xbdr\xb2\xe2=Mv\x82=\x19\xef\xc2=',
#                  'dims': [10, 20],
#                  'data_type': FLOAT},
#                 'bias': {'name': 'linear1.bias',
#                  'raw_data': b'U\xd2\x8a=:\xd4\x00\xbe\xc7\x1f`\xbe\xc7 7>\xcc\x93]>\x92\xf2G\xbe\xdd\x1e\x18>\xd5S\xdb<\x16\x1e\x1f=~7\xbd\xbb',
#                  'dims': [10],
#                  'data_type': FLOAT}},
#                'attributes': OrderedDict(),
#                'data_layout': None}),
#              (8,
#               {'name': 'Relu_8',
#                'op_type': RELU,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {}, 'bias': {}},
#                'attributes': OrderedDict(),
#                'data_layout': None}),
#              (9,
#               {'name': 'Gemm_9',
#                'op_type': LINEAR,
#                'inputs': None,
#                'outputs': None,
#                'initializer': {'weight': {'name': 'linear2.weight',
#                  'raw_data': b'J!\xbf;\xc1 \x8c\xbe\xe8\xd5\r>\xa2\x86\x91>\xa2\\N>^n\x83\xbe\x97W\x8d=\xad\xbe\x89=B\x90\xde=r\xbd\x08>/F\x88\xbe\x1d\xc7\x94\xbe|\x0b\x90\xbeG\xca!\xbe\x03\xe6\x83=\xf8\x8f\xdf=6\x80\x94\xbe\xd5.\x98>@\x0c~>\xfeE\x9f=\xa0\xce\x9b\xbe^ R>\xfdL\x00>)m\x8f>\xf2q0\xbe[\x07\x01\xbe\xae\xd5^>\xbe\xb8\xcc=\x88\r\x89>\xae\xc2+\xbd\xffFh\xbd\x87<\x97>V\xc6\xb8=B|\x0c\xbe\xc4U)>\x8f\xa1\x92\xbd\xb8>\x87\xbe\xf8\xe5m\xbe\x95\xac\x91>\x04\n\x8d>%_a\xbe\xac\x95$\xbe\x9dfQ>\xe9\x7f\\>\xd1L\x93>\x0e\xe6\x94=\x99\xa5\x83>.{\x02\xbd\xb1\xcb\x9b=\xe0ab\xbd\xb3\xb1\x93>\xae\x9e\x83\xbe\xb96\xba\xbd#.a>\xad\xfc\xe0=\x80\xfbs\xbe\xac\xb5k\xbd\x88\xd9\x1f\xbd\x0b\xf1\xc1=\xae\xcc\x85>Kb*>\xc2\xe2\xb5=\x80\x87\xfe=\xc1\x8e\xa1>\x94\xf7\xfa=\x03\x10\x94\xbe\xf2\xcd\x99\xbe\xdfJ\xb8\xbd\xea9\x05\xbe@\x97\r>\x13\xfa\xf4\xbdLJb\xbe\xc6\x8f\x8f=\xcf\x9f\x99\xbeX\xbdH\xbeY\xc7g>\x7fLa>\xc3\x05\xa6\xbd\xad\xc27\xbe}\xab\xf4=\x9cO\x14=U\x1a?>v\xffT\xbeB\x14\xfb=\xafK\\\xbe(\x8e\xed=\xc8W\x97\xbe\x00\x022=\xe1\x01c>\x89\xbeq\xbe\x1b\xaf@<W\xdfz\xbey\xa2\x8e>U\xfc\x91\xbe&Q\x05\xbe\x1f\x07\xfc\xbd\x9a\xbb\xe1=2\xc1\x88>Hh\x03\xbe\xf1@g>',
#                  'dims': [10, 10],
#                  'data_type': FLOAT},
#                 'bias': {'name': 'linear2.bias',
#                  'raw_data': b'\x83\x98\x16=i\x07\xfb\xbdN \x87\xbe\x05\xeb\xb5\xbc\xce\x06B\xbd|\xcf\x17\xbe\x99j[\xbe\xc7\xb6\xa4\xbd\x84\xbc\x9b\xbe\r\xa5\xdb\xbd',
#                  'dims': [10],
#                  'data_type': FLOAT}},
#                'attributes': OrderedDict(),
#                'data_layout': None})])

# %%
model_onnx.graph.node[2]
# Out:
# input: "input.1"
# input: "conv2.weight"
# input: "conv2.bias"
# output: "x.3"
# name: "Conv_2"
# op_type: "Conv"
# attribute {
#   name: "dilations"
#   ints: 1
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "group"
#   i: 1
#   type: INT
# }
# attribute {
#   name: "kernel_shape"
#   ints: 4
#   ints: 4
#   type: INTS
# }
# attribute {
#   name: "pads"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "strides"
#   ints: 2
#   ints: 2
#   type: INTS
# }

# %%
for inp in model_onnx.graph.node[0].input:
    for initializer in model_onnx.graph.initializer:
        if inp == initializer.name:
            print(inp)
# Out:
# conv1.weight
# conv1.bias

# %%
model_onnx.graph.node[0].input
# Out:
# ['input', 'conv1.weight', 'conv1.bias']
